# %%
print ("hello class,how are you")
# Out:
# hello class,how are you

# %% [markdown]
#  There was not error.

# %%
print ("1")
# Out:
# 1

# %% [markdown]
# It is getting good

# %%
print ("2")
# Out:
# 2

# %%
print ("3")
# Out:
# 3

# %% [markdown]
# Printing 2 and 3 were okay

# %%
 print ("hello class - Section - A")
# Out:
# hello class - Section - A

# %% [markdown]
# This has to be really careful especially about having space.

# %%
print ("hello class - Section -B")
# Out:
# hello class - Section -B
